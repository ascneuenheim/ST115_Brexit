# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException, TimeoutException

# Setup ChromeDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
search_url = "https://eprints.lse.ac.uk/cgi/search/advanced"
driver.get(search_url)

# Prepare a DataFrame for storing results
columns = ['Department'] + [str(year) for year in range(2010, 2024)]
results_df = pd.DataFrame(columns=columns)

# List of departments
departments = [
    'Geography & Environment', 'Philosophy, Logic and Scientific Method', 
    'Psychological and Behavioural Science', 'Government', 'Law', 
    'Social Policy', 'Mathematics', 'Economic History', 'Sociology', 
    'International History', 'Statistics', 'Management', 'International Relations', 
    'Anthropology', 'Economics', 'Language Centre', 'Accounting', 'Finance', 
    'Methodology', 'School of Public Policy', 
    'European Institute', 'Media and Communications', 'Health Policy', 
    'International Development', 'Gender Studies'
]

# Process each department
for department in departments:
    row_data = {'Department': department}
    driver.get(search_url)  # Navigate back to the main search page for each department
    try:
        divisions_select = Select(driver.find_element(By.ID, "divisions"))  # Locate the dropdown again
        divisions_select.select_by_visible_text(department)
        available = True
    except NoSuchElementException:
        available = False
        print(f"Department {department} not found.")
    
    if available:
        for year in range(2010, 2024):
            try:
                wait = WebDriverWait(driver, 5)
                date_input = wait.until(EC.visibility_of_element_located((By.CSS_SELECTOR, "input[name='date']")))
                date_input.clear()
                date_input.send_keys(str(year))
                date_input.send_keys(Keys.RETURN)

                # Wait for the page to load and scrape the total results
                total_results_elements = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "span.ep_search_number")))
                total_results = total_results_elements[-1].text  # Get the text of the last element
                row_data[str(year)] = total_results
                print(f"Results for {department} in {year}: {total_results}")
            except NoSuchElementException:
                row_data[str(year)] = 'Element not found'
                print(f"Element not found for {department} in {year}.")
            except TimeoutException:
                row_data[str(year)] = 'Timeout or no results'
                print(f"Timeout or no results for {department} in {year}.")
            driver.get('https://eprints.lse.ac.uk/cgi/search/archive/advanced')
            divisions_select = Select(driver.find_element(By.ID, "divisions"))  # Locate the dropdown again
            divisions_select.select_by_visible_text(department)
    # Append the results of this department to the DataFrame and save incrementally
    new_row = pd.DataFrame([row_data])
    results_df = pd.concat([results_df, new_row], ignore_index=True)
    results_df.to_csv('department_yearly_results.csv', index=False)

# Close the browser
driver.quit()

print("Data scraping completed and saved to 'Data/department_yearly_results.csv'.")
# Out:
# Results for Geography & Environment in 2010: 220
# Results for Geography & Environment in 2011: 296
# Results for Geography & Environment in 2012: 243
# Results for Geography & Environment in 2013: 160
# Results for Geography & Environment in 2014: 160
# Results for Geography & Environment in 2015: 108
# Results for Geography & Environment in 2016: 129
# Results for Geography & Environment in 2017: 119
# Results for Geography & Environment in 2018: 119
# Results for Geography & Environment in 2019: 117
# Results for Geography & Environment in 2020: 175
# Results for Geography & Environment in 2021: 177
# Results for Geography & Environment in 2022: 170
# Results for Geography & Environment in 2023: 145
# Results for Philosophy, Logic and Scientific Method in 2010: 98
# Results for Philosophy, Logic and Scientific Method in 2011: 60
# Results for Philosophy, Logic and Scientific Method in 2012: 66
# Results for Philosophy, Logic and Scientific Method in 2013: 68
# Results for Philosophy, Logic and Scientific Method in 2014: 46
# Results for Philosophy, Logic and Scientific Method in 2015: 60
# Results for Philosophy, Logic and Scientific Method in 2016: 50
# Results for Philosophy, Logic and Scientific Method in 2017: 69
# Results for Philosophy, Logic and Scientific Method in 2018: 55
# Results for Philosophy, Logic and Scientific Method in 2019: 64
# Results for Philosophy, Logic and Scientific Method in 2020: 60
# Results for Philosophy, Logic and Scientific Method in 2021: 63
# Results for Philosophy, Logic and Scientific Method in 2022: 66
# Results for Philosophy, Logic and Scientific Method in 2023: 61
# Results for Psychological and Behavioural Science in 2010: 79
# Results for Psychological and Behavioural Science in 2011: 116
# Results for Psychological and Behavioural Science in 2012: 69
# Results for Psychological and Behavioural Science in 2013: 99
# Results for Psychological and Behavioural Science in 2014: 88
# Results for Psychological and Behavioural Science in 2015: 92
# Results for Psychological and Behavioural Science in 2016: 84
# Results for Psychological and Behavioural Science in 2017: 77
# Results for Psychological and Behavioural Science in 2018: 91
# Results for Psychological and Behavioural Science in 2019: 77
# Results for Psychological and Behavioural Science in 2020: 125
# Results for Psychological and Behavioural Science in 2021: 152
# Results for Psychological and Behavioural Science in 2022: 156
# Results for Psychological and Behavioural Science in 2023: 146
# Results for Government in 2010: 274
# Results for Government in 2011: 211
# Results for Government in 2012: 227
# Results for Government in 2013: 190
# Results for Government in 2014: 160
# Results for Government in 2015: 156
# Results for Government in 2016: 190
# Results for Government in 2017: 142
# Results for Government in 2018: 302
# Results for Government in 2019: 106
# Results for Government in 2020: 126
# Results for Government in 2021: 85
# Results for Government in 2022: 100
# Results for Government in 2023: 113
# Results for Law in 2010: 248
# Results for Law in 2011: 205
# Results for Law in 2012: 245
# Results for Law in 2013: 192
# Results for Law in 2014: 174
# Results for Law in 2015: 164
# Results for Law in 2016: 204
# Results for Law in 2017: 180
# Results for Law in 2018: 160
# Results for Law in 2019: 85
# Results for Law in 2020: 118
# Results for Law in 2021: 146
# Results for Law in 2022: 92
# Results for Law in 2023: 117
# Results for Social Policy in 2010: 267
# Results for Social Policy in 2011: 342
# Results for Social Policy in 2012: 325
# Results for Social Policy in 2013: 305
# Results for Social Policy in 2014: 327
# Results for Social Policy in 2015: 283
# Results for Social Policy in 2016: 216
# Results for Social Policy in 2017: 196
# Results for Social Policy in 2018: 154
# Results for Social Policy in 2019: 112
# Results for Social Policy in 2020: 124
# Results for Social Policy in 2021: 116
# Results for Social Policy in 2022: 138
# Results for Social Policy in 2023: 142
# Results for Mathematics in 2010: 67
# Results for Mathematics in 2011: 49
# Results for Mathematics in 2012: 43
# Results for Mathematics in 2013: 64
# Results for Mathematics in 2014: 42
# Results for Mathematics in 2015: 45
# Results for Mathematics in 2016: 58
# Results for Mathematics in 2017: 64
# Results for Mathematics in 2018: 50
# Results for Mathematics in 2019: 53
# Results for Mathematics in 2020: 91
# Results for Mathematics in 2021: 56
# Results for Mathematics in 2022: 64
# Results for Mathematics in 2023: 50
# Results for Economic History in 2010: 87
# Results for Economic History in 2011: 102
# Results for Economic History in 2012: 104
# Results for Economic History in 2013: 59
# Results for Economic History in 2014: 51
# Results for Economic History in 2015: 33
# Results for Economic History in 2016: 50
# Results for Economic History in 2017: 45
# Results for Economic History in 2018: 50
# Results for Economic History in 2019: 49
# Results for Economic History in 2020: 44
# Results for Economic History in 2021: 38
# Results for Economic History in 2022: 38
# Results for Economic History in 2023: 53
# Results for Sociology in 2010: 99
# Results for Sociology in 2011: 77
# Results for Sociology in 2012: 92
# Results for Sociology in 2013: 92
# Results for Sociology in 2014: 70
# Results for Sociology in 2015: 91
# Results for Sociology in 2016: 103
# Results for Sociology in 2017: 70
# Results for Sociology in 2018: 68
# Results for Sociology in 2019: 45
# Results for Sociology in 2020: 54
# Results for Sociology in 2021: 59
# Results for Sociology in 2022: 57
# Results for Sociology in 2023: 50
# Results for International History in 2010: 79
# Results for International History in 2011: 89
# Results for International History in 2012: 71
# Results for International History in 2013: 68
# Results for International History in 2014: 65
# Results for International History in 2015: 43
# Results for International History in 2016: 67
# Results for International History in 2017: 49
# Results for International History in 2018: 56
# Results for International History in 2019: 41
# Results for International History in 2020: 43
# Results for International History in 2021: 37
# Results for International History in 2022: 35
# Results for International History in 2023: 32
# Results for Statistics in 2010: 56
# Results for Statistics in 2011: 63
# Results for Statistics in 2012: 51
# Results for Statistics in 2013: 57
# Results for Statistics in 2014: 37
# Results for Statistics in 2015: 52
# Results for Statistics in 2016: 44
# Results for Statistics in 2017: 67
# Results for Statistics in 2018: 53
# Results for Statistics in 2019: 42
# Results for Statistics in 2020: 63
# Results for Statistics in 2021: 54
# Results for Statistics in 2022: 84
# Results for Statistics in 2023: 94
# Results for Management in 2010: 234
# Results for Management in 2011: 225
# Results for Management in 2012: 187
# Results for Management in 2013: 228
# Results for Management in 2014: 161
# Results for Management in 2015: 152
# Results for Management in 2016: 167
# Results for Management in 2017: 151
# Results for Management in 2018: 114
# Results for Management in 2019: 87
# Results for Management in 2020: 114
# Results for Management in 2021: 108
# Results for Management in 2022: 112
# Results for Management in 2023: 94
# Results for International Relations in 2010: 183
# Results for International Relations in 2011: 183
# Results for International Relations in 2012: 148
# Results for International Relations in 2013: 120
# Results for International Relations in 2014: 138
# Results for International Relations in 2015: 145
# Results for International Relations in 2016: 120
# Results for International Relations in 2017: 149
# Results for International Relations in 2018: 89
# Results for International Relations in 2019: 85
# Results for International Relations in 2020: 90
# Results for International Relations in 2021: 91
# Results for International Relations in 2022: 93
# Results for International Relations in 2023: 101
# Results for Anthropology in 2010: 81
# Results for Anthropology in 2011: 97
# Results for Anthropology in 2012: 96
# Results for Anthropology in 2013: 91
# Results for Anthropology in 2014: 44
# Results for Anthropology in 2015: 61
# Results for Anthropology in 2016: 39
# Results for Anthropology in 2017: 55
# Results for Anthropology in 2018: 45
# Results for Anthropology in 2019: 36
# Results for Anthropology in 2020: 51
# Results for Anthropology in 2021: 47
# Results for Anthropology in 2022: 57
# Results for Anthropology in 2023: 50
# Results for Economics in 2010: 164
# Results for Economics in 2011: 171
# Results for Economics in 2012: 149
# Results for Economics in 2013: 164
# Results for Economics in 2014: 115
# Results for Economics in 2015: 100
# Results for Economics in 2016: 120
# Results for Economics in 2017: 107
# Results for Economics in 2018: 97
# Results for Economics in 2019: 114
# Results for Economics in 2020: 194
# Results for Economics in 2021: 139
# Results for Economics in 2022: 142
# Results for Economics in 2023: 134
# Timeout or no results for Language Centre in 2010.
# Timeout or no results for Language Centre in 2011.
# Timeout or no results for Language Centre in 2012.
# Timeout or no results for Language Centre in 2013.
# Timeout or no results for Language Centre in 2014.
# Timeout or no results for Language Centre in 2015.
# Timeout or no results for Language Centre in 2016.
# Timeout or no results for Language Centre in 2017.
# Timeout or no results for Language Centre in 2018.
# Timeout or no results for Language Centre in 2019.
# Timeout or no results for Language Centre in 2020.
# Timeout or no results for Language Centre in 2021.
# Timeout or no results for Language Centre in 2022.
# Timeout or no results for Language Centre in 2023.
# Results for Accounting in 2010: 51
# Results for Accounting in 2011: 32
# Results for Accounting in 2012: 41
# Results for Accounting in 2013: 35
# Results for Accounting in 2014: 30
# Results for Accounting in 2015: 34
# Results for Accounting in 2016: 41
# Results for Accounting in 2017: 32
# Results for Accounting in 2018: 25
# Results for Accounting in 2019: 22
# Results for Accounting in 2020: 16
# Results for Accounting in 2021: 25
# Results for Accounting in 2022: 30
# Results for Accounting in 2023: 14
# Results for Finance in 2010: 37
# Results for Finance in 2011: 61
# Results for Finance in 2012: 57
# Results for Finance in 2013: 48
# Results for Finance in 2014: 43
# Results for Finance in 2015: 43
# Results for Finance in 2016: 58
# Results for Finance in 2017: 23
# Results for Finance in 2018: 32
# Results for Finance in 2019: 22
# Results for Finance in 2020: 37
# Results for Finance in 2021: 33
# Results for Finance in 2022: 30
# Results for Finance in 2023: 30
# Results for Methodology in 2010: 37
# Results for Methodology in 2011: 43
# Results for Methodology in 2012: 40
# Results for Methodology in 2013: 55
# Results for Methodology in 2014: 42
# Results for Methodology in 2015: 55
# Results for Methodology in 2016: 53
# Results for Methodology in 2017: 60
# Results for Methodology in 2018: 60
# Results for Methodology in 2019: 39
# Results for Methodology in 2020: 76
# Results for Methodology in 2021: 58
# Results for Methodology in 2022: 64
# Results for Methodology in 2023: 72
# Results for School of Public Policy in 2010: 23
# Results for School of Public Policy in 2011: 18
# Results for School of Public Policy in 2012: 3
# Results for School of Public Policy in 2013: 4
# Results for School of Public Policy in 2014: 2
# Results for School of Public Policy in 2015: 5
# Results for School of Public Policy in 2016: 7
# Results for School of Public Policy in 2017: 5
# Results for School of Public Policy in 2018: 160
# Results for School of Public Policy in 2019: 18
# Results for School of Public Policy in 2020: 34
# Results for School of Public Policy in 2021: 50
# Results for School of Public Policy in 2022: 26
# Results for School of Public Policy in 2023: 41
# Results for European Institute in 2010: 174
# Results for European Institute in 2011: 174
# Results for European Institute in 2012: 243
# Results for European Institute in 2013: 187
# Results for European Institute in 2014: 154
# Results for European Institute in 2015: 145
# Results for European Institute in 2016: 183
# Results for European Institute in 2017: 117
# Results for European Institute in 2018: 321
# Results for European Institute in 2019: 63
# Results for European Institute in 2020: 147
# Results for European Institute in 2021: 86
# Results for European Institute in 2022: 99
# Results for European Institute in 2023: 93
# Results for Media and Communications in 2010: 250
# Results for Media and Communications in 2011: 243
# Results for Media and Communications in 2012: 229
# Results for Media and Communications in 2013: 243
# Results for Media and Communications in 2014: 187
# Results for Media and Communications in 2015: 178
# Results for Media and Communications in 2016: 195
# Results for Media and Communications in 2017: 176
# Results for Media and Communications in 2018: 103
# Results for Media and Communications in 2019: 89
# Results for Media and Communications in 2020: 125
# Results for Media and Communications in 2021: 141
# Results for Media and Communications in 2022: 133
# Results for Media and Communications in 2023: 137
# Results for Health Policy in 2010: 11
# Results for Health Policy in 2011: 10
# Results for Health Policy in 2012: 11
# Results for Health Policy in 2013: 8
# Results for Health Policy in 2014: 15
# Results for Health Policy in 2015: 27
# Results for Health Policy in 2016: 19
# Results for Health Policy in 2017: 39
# Results for Health Policy in 2018: 80
# Results for Health Policy in 2019: 100
# Results for Health Policy in 2020: 149
# Results for Health Policy in 2021: 178
# Results for Health Policy in 2022: 189
# Results for Health Policy in 2023: 206
# Results for International Development in 2010: 117
# Results for International Development in 2011: 92
# Results for International Development in 2012: 104
# Results for International Development in 2013: 128
# Results for International Development in 2014: 115
# Results for International Development in 2015: 143
# Results for International Development in 2016: 110
# Results for International Development in 2017: 102
# Results for International Development in 2018: 90
# Results for International Development in 2019: 111
# Results for International Development in 2020: 127
# Results for International Development in 2021: 104
# Results for International Development in 2022: 89
# Results for International Development in 2023: 80
# Results for Gender Studies in 2010: 58
# Results for Gender Studies in 2011: 44
# Results for Gender Studies in 2012: 52
# Results for Gender Studies in 2013: 40
# Results for Gender Studies in 2014: 40
# Results for Gender Studies in 2015: 41
# Results for Gender Studies in 2016: 34
# Results for Gender Studies in 2017: 23
# Results for Gender Studies in 2018: 28
# Results for Gender Studies in 2019: 19
# Results for Gender Studies in 2020: 21
# Results for Gender Studies in 2021: 20
# Results for Gender Studies in 2022: 18
# Results for Gender Studies in 2023: 24
# Data scraping completed and saved to 'Data/department_yearly_results.csv'.

# %%
###########FINISHED 15:08


import pandas as pd
import pdfplumber
import csv

def find_next_containing_row(data_frame, start_index, column_index, text):
    for idx in range(start_index, len(data_frame)):
        cell_content = str(data_frame.iloc[idx, column_index])
        if pd.notna(cell_content) and text in cell_content:
            return idx
    return None

def find_first_non_empty_cell_and_extract_fee(data_frame, start_index, column_index):
    for idx in range(start_index, min(start_index + 10, len(data_frame))):
        cell_content = data_frame.iloc[idx, column_index]
        if pd.notna(cell_content) and cell_content != '':
            first_word = cell_content.split()[0]
            fee = ''.join(filter(str.isdigit, first_word))
            fee = fee.replace(',', '')
            return fee
    print("No non-empty cell found within the specified range.")
    return None

def clean_course_name(course_name):
    return str(course_name).replace('MSc in', 'MSc').strip()  # Removes 'MSc in' and trims any leading/trailing whitespace

def integrate_and_process_data(year):
    cleaned_fees_output_path = f'Test/CleanedFees{year}.csv'
    grouped_output_path = f'Test/Grouped_Fees{year}_by_Department_and_Level.csv'

    # Load the cleaned fees data and the department information
    cleaned_fees_df = pd.read_csv(cleaned_fees_output_path)
    department_info_df = pd.read_csv('data/PhilipOutput.csv')

    # Define a function to find the department for a given course name
    def find_department(course_name, department_df):
        match = department_df[department_df['Course Name'].str.strip().eq(course_name.strip())]
        if not match.empty:
            return match['Department'].iloc[0]
        return "Department not found"

    # Apply the function to add a new 'Department' column to the cleaned fees DataFrame
    cleaned_fees_df['Department'] = cleaned_fees_df['Course'].apply(lambda x: find_department(x, department_info_df))

    # Convert the Home Fee and Overseas Fee columns to numeric values for calculation
    cleaned_fees_df['Home Fee'] = pd.to_numeric(cleaned_fees_df['Home Fee'], errors='coerce')
    cleaned_fees_df['Overseas Fee'] = pd.to_numeric(cleaned_fees_df['Overseas Fee'], errors='coerce')

    # Calculate the fee difference and add it as a new column
    cleaned_fees_df['Fee Difference'] = cleaned_fees_df['Overseas Fee'] - cleaned_fees_df['Home Fee']

    # Group the data by 'Department' and 'Level', and calculate the average fee difference for each group
    grouped_data = cleaned_fees_df.groupby(['Department', 'Level']).agg({
        'Fee Difference': 'mean'
    }).reset_index()

    # Save the grouped data to a new CSV file
    grouped_data.to_csv(grouped_output_path, index=False, encoding='utf-8-sig')

    # Output the path to the saved file to confirm where it has been saved
    print(f"Grouped data for {year} saved to:", grouped_output_path)

    # Display the grouped data for verification
    display(grouped_data)

def extract_tables_from_pdf(pdf_path, output_csv_path):
    with pdfplumber.open(pdf_path) as pdf:
        all_tables = []
        for page in pdf.pages:
            tables = page.extract_tables()
            for table in tables:
                for row in table:
                    while len(row) < 10:
                        row.append('')
                    processed_row = row[:3] + [''] * 7
                    all_tables.append(processed_row)
        with open(output_csv_path, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            for row in all_tables:
                writer.writerow(row)

for year in range(2018, 2025):  # from 2018 to 2024
    pdf_path = f'Data/TuitionFees/Fees{year}.pdf'
    output_csv_path = f'Test/Fees{year}.csv'
    updated_all_courses_output_path = f'Test/CleanedFees{year}.csv'

    extract_tables_from_pdf(pdf_path, output_csv_path)
    fees_df = pd.read_csv(output_csv_path, encoding='latin-1')

    home_fee_index = find_next_containing_row(fees_df, 0, 1, "Home")
    undergrad_home_fee = find_first_non_empty_cell_and_extract_fee(fees_df, home_fee_index + 1, 1)
    overseas_fee_index = find_next_containing_row(fees_df, 0, 2, "Overseas")
    undergrad_overseas_fee = find_first_non_empty_cell_and_extract_fee(fees_df, overseas_fee_index + 1, 2)

    has_undergraduate = False
    all_courses_fees_detailed = []
    for index, row in fees_df.iterrows():
        if isinstance(row.iloc[0], str) and any(x in row.iloc[0] for x in ['BSc', 'BA', 'MSc']):
            course_name = clean_course_name(row.iloc[0].split(' - ')[0])
            level = "Postgraduate" if "MSc" in course_name else "Undergraduate"
            if level == "Undergraduate":
                has_undergraduate = True
            home_fee = row.iloc[1] if not pd.isna(row.iloc[1]) else (undergrad_home_fee if level == "Undergraduate" else '')
            overseas_fee = row.iloc[2] if not pd.isna(row.iloc[2]) else ''
            home_fee = ''.join(filter(str.isdigit, home_fee))
            overseas_fee = ''.join(filter(str.isdigit, overseas_fee))
            all_courses_fees_detailed.append([course_name, home_fee, overseas_fee, level])

    if not has_undergraduate:
        all_courses_fees_detailed.append(["Undergraduate Courses", undergrad_home_fee, undergrad_overseas_fee, "Undergraduate"])

    all_courses_df_detailed = pd.DataFrame(all_courses_fees_detailed, columns=['Course', 'Home Fee', 'Overseas Fee', 'Level'])
    all_courses_df_detailed.to_csv(updated_all_courses_output_path, index=False, encoding='utf-8-sig')

    print(f"Processed data for {year}.")

    # Integrate and process the data for the current year
    integrate_and_process_data(year)
# Out:
# Processed data for 2018.
# Grouped data for 2018 saved to: Test/Grouped_Fees2018_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                          Department of Anthropology   Postgraduate
# 4                      Department of Economic History   Postgraduate
# 5                        Department of Gender Studies   Postgraduate
# 6             Department of Geography and Environment   Postgraduate
# 7                         Department of Health Policy   Postgraduate
# 8             Department of International Development   Postgraduate
# 9                           Department of Mathematics   Postgraduate
# 10             Department of Media and Communications   Postgraduate
# 11                          Department of Methodology   Postgraduate
# 12  Department of Philosophy Logic and Scientific ...   Postgraduate
# 13  Department of Psychological and Behavioural Sc...   Postgraduate
# 14                        Department of Social Policy   Postgraduate
# 15                            Department of Sociology   Postgraduate
# 16                           Department of Statistics   Postgraduate
# 17                                 European Institute   Postgraduate
#
#     Fee Difference
# 0      2542.500000
# 1      9902.000000
# 2       528.000000
# 3      7368.000000
# 4      7368.000000
# 5      7368.000000
# 6      6315.428571
# 7              NaN
# 8      4912.000000
# 9      3948.000000
# 10        0.000000
# 11     3948.000000
# 12     3684.000000
# 13     7368.000000
# 14    10176.000000
# 15     5937.600000
# 16      528.000000
# 17        0.000000
# Processed data for 2019.
# Grouped data for 2019 saved to: Test/Grouped_Fees2019_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                          Department of Anthropology   Postgraduate
# 4                      Department of Economic History   Postgraduate
# 5                        Department of Gender Studies   Postgraduate
# 6             Department of Geography and Environment   Postgraduate
# 7                            Department of Government   Postgraduate
# 8                         Department of Health Policy   Postgraduate
# 9             Department of International Development   Postgraduate
# 10                          Department of Mathematics   Postgraduate
# 11             Department of Media and Communications   Postgraduate
# 12                          Department of Methodology   Postgraduate
# 13  Department of Philosophy Logic and Scientific ...   Postgraduate
# 14  Department of Psychological and Behavioural Sc...   Postgraduate
# 15                        Department of Social Policy   Postgraduate
# 16                            Department of Sociology   Postgraduate
# 17                           Department of Statistics   Postgraduate
# 18                                 European Institute   Postgraduate
#
#     Fee Difference
# 0      2321.540984
# 1     10670.000000
# 2       552.000000
# 3      7656.000000
# 4      7656.000000
# 5      7656.000000
# 6      6657.000000
# 7      7656.000000
# 8      7320.000000
# 9      3828.000000
# 10     4104.000000
# 11        0.000000
# 12     4104.000000
# 13     3828.000000
# 14     3828.000000
# 15     7656.000000
# 16     6545.142857
# 17      552.000000
# 18        0.000000
# Processed data for 2020.
# Grouped data for 2020 saved to: Test/Grouped_Fees2020_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                          Department of Anthropology   Postgraduate
# 4                      Department of Economic History   Postgraduate
# 5                        Department of Gender Studies   Postgraduate
# 6             Department of Geography and Environment   Postgraduate
# 7                            Department of Government   Postgraduate
# 8                         Department of Health Policy   Postgraduate
# 9             Department of International Development   Postgraduate
# 10                          Department of Mathematics   Postgraduate
# 11             Department of Media and Communications   Postgraduate
# 12                          Department of Methodology   Postgraduate
# 13  Department of Philosophy Logic and Scientific ...   Postgraduate
# 14  Department of Psychological and Behavioural Sc...   Postgraduate
# 15                        Department of Social Policy   Postgraduate
# 16                            Department of Sociology   Postgraduate
# 17                           Department of Statistics   Postgraduate
# 18                                 European Institute   Postgraduate
#
#     Fee Difference
# 0      2362.983051
# 1     12320.000000
# 2       576.000000
# 3      7968.000000
# 4      7968.000000
# 5      7968.000000
# 6      6837.000000
# 7      7968.000000
# 8      7608.000000
# 9      3984.000000
# 10     4272.000000
# 11        0.000000
# 12     4272.000000
# 13     3984.000000
# 14     3984.000000
# 15     7968.000000
# 16     6809.142857
# 17      576.000000
# 18        0.000000
# Processed data for 2021.
# Grouped data for 2021 saved to: Test/Grouped_Fees2021_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                          Department of Anthropology   Postgraduate
# 4                      Department of Economic History   Postgraduate
# 5                        Department of Gender Studies   Postgraduate
# 6             Department of Geography and Environment   Postgraduate
# 7                            Department of Government   Postgraduate
# 8                         Department of Health Policy   Postgraduate
# 9             Department of International Development   Postgraduate
# 10                          Department of Mathematics   Postgraduate
# 11             Department of Media and Communications   Postgraduate
# 12                          Department of Methodology   Postgraduate
# 13  Department of Philosophy Logic and Scientific ...   Postgraduate
# 14  Department of Psychological and Behavioural Sc...   Postgraduate
# 15                        Department of Social Policy   Postgraduate
# 16                            Department of Sociology   Postgraduate
# 17                           Department of Statistics   Postgraduate
# 18                                 European Institute   Postgraduate
#
#     Fee Difference
# 0      2409.684211
# 1     13180.000000
# 2       600.000000
# 3      8304.000000
# 4      8304.000000
# 5      8304.000000
# 6      6328.000000
# 7      8304.000000
# 8      5264.000000
# 9      4152.000000
# 10     4452.000000
# 11        0.000000
# 12     4452.000000
# 13     4152.000000
# 14     4152.000000
# 15     8304.000000
# 16     7086.857143
# 17      600.000000
# 18        0.000000
# Processed data for 2022.
# Grouped data for 2022 saved to: Test/Grouped_Fees2022_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                          Department of Anthropology   Postgraduate
# 4                      Department of Economic History   Postgraduate
# 5                        Department of Gender Studies   Postgraduate
# 6             Department of Geography and Environment   Postgraduate
# 7                            Department of Government   Postgraduate
# 8                         Department of Health Policy   Postgraduate
# 9             Department of International Development   Postgraduate
# 10                          Department of Mathematics   Postgraduate
# 11             Department of Media and Communications   Postgraduate
# 12                          Department of Methodology   Postgraduate
# 13  Department of Philosophy Logic and Scientific ...   Postgraduate
# 14  Department of Psychological and Behavioural Sc...   Postgraduate
# 15                            Department of Sociology   Postgraduate
# 16                           Department of Statistics   Postgraduate
# 17                                 European Institute   Postgraduate
#
#     Fee Difference
# 0      2761.655172
# 1     14080.000000
# 2       624.000000
# 3      8640.000000
# 4      8640.000000
# 5      8640.000000
# 6      6536.000000
# 7         0.000000
# 8      5472.000000
# 9      4320.000000
# 10     4632.000000
# 11        0.000000
# 12     4632.000000
# 13     4320.000000
# 14     4320.000000
# 15     7527.000000
# 16      624.000000
# 17        0.000000
# Processed data for 2023.
# Grouped data for 2023 saved to: Test/Grouped_Fees2023_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                            Department of Accounting  Undergraduate
# 4                          Department of Anthropology   Postgraduate
# 5                          Department of Anthropology  Undergraduate
# 6                      Department of Economic History   Postgraduate
# 7                      Department of Economic History  Undergraduate
# 8                             Department of Economics  Undergraduate
# 9                               Department of Finance  Undergraduate
# 10                       Department of Gender Studies   Postgraduate
# 11            Department of Geography and Environment   Postgraduate
# 12            Department of Geography and Environment  Undergraduate
# 13                           Department of Government   Postgraduate
# 14                           Department of Government  Undergraduate
# 15                        Department of Health Policy   Postgraduate
# 16            Department of International Development   Postgraduate
# 17                Department of International History  Undergraduate
# 18              Department of International Relations  Undergraduate
# 19                           Department of Management  Undergraduate
# 20                          Department of Mathematics   Postgraduate
# 21                          Department of Mathematics  Undergraduate
# 22             Department of Media and Communications   Postgraduate
# 23                          Department of Methodology   Postgraduate
# 24  Department of Philosophy Logic and Scientific ...   Postgraduate
# 25  Department of Philosophy, Logic and Scientific...  Undergraduate
# 26  Department of Psychological and Behavioural Sc...   Postgraduate
# 27                            Department of Sociology   Postgraduate
# 28                            Department of Sociology  Undergraduate
# 29                           Department of Statistics   Postgraduate
# 30                           Department of Statistics  Undergraduate
# 31                                 European Institute   Postgraduate
#
#     Fee Difference
# 0           2865.5
# 1          15626.0
# 2            648.0
# 3          16406.0
# 4           9480.0
# 5          15470.0
# 6           9480.0
# 7          16094.0
# 8          17342.0
# 9          17342.0
# 10          9480.0
# 11          7200.0
# 12         15938.0
# 13             0.0
# 14         16218.8
# 15          6048.0
# 16          9480.0
# 17         15470.0
# 18         16406.0
# 19         16406.0
# 20          5064.0
# 21         16406.0
# 22             0.0
# 23          5064.0
# 24          4740.0
# 25         16718.0
# 26          4740.0
# 27          9720.0
# 28         15470.0
# 29           648.0
# 30         16406.0
# 31             0.0
# Processed data for 2024.
# Grouped data for 2024 saved to: Test/Grouped_Fees2024_by_Department_and_Level.csv
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                            Department of Accounting  Undergraduate
# 4                          Department of Anthropology   Postgraduate
# 5                          Department of Anthropology  Undergraduate
# 6                      Department of Economic History   Postgraduate
# 7                      Department of Economic History  Undergraduate
# 8                             Department of Economics  Undergraduate
# 9                               Department of Finance  Undergraduate
# 10                       Department of Gender Studies   Postgraduate
# 11            Department of Geography and Environment   Postgraduate
# 12            Department of Geography and Environment  Undergraduate
# 13                           Department of Government   Postgraduate
# 14                           Department of Government  Undergraduate
# 15                        Department of Health Policy   Postgraduate
# 16            Department of International Development   Postgraduate
# 17                Department of International History  Undergraduate
# 18              Department of International Relations  Undergraduate
# 19                           Department of Management  Undergraduate
# 20                          Department of Mathematics   Postgraduate
# 21                          Department of Mathematics  Undergraduate
# 22             Department of Media and Communications   Postgraduate
# 23                          Department of Methodology   Postgraduate
# 24  Department of Philosophy Logic and Scientific ...   Postgraduate
# 25  Department of Philosophy, Logic and Scientific...  Undergraduate
# 26  Department of Psychological and Behavioural Sc...   Postgraduate
# 27                        Department of Social Policy  Undergraduate
# 28                            Department of Sociology   Postgraduate
# 29                            Department of Sociology  Undergraduate
# 30                           Department of Statistics   Postgraduate
# 31                           Department of Statistics  Undergraduate
# 32                                 European Institute   Postgraduate
#
#     Fee Difference
# 0      2964.000000
# 1     17270.000000
# 2       696.000000
# 3     17942.000000
# 4     10056.000000
# 5     16934.000000
# 6      6024.000000
# 7     17598.000000
# 8     18926.000000
# 9     18926.000000
# 10    10056.000000
# 11     8597.333333
# 12    17438.000000
# 13        0.000000
# 14    17740.400000
# 15     6416.000000
# 16    10056.000000
# 17    16934.000000
# 18    17942.000000
# 19    17942.000000
# 20     5376.000000
# 21    17942.000000
# 22        0.000000
# 23     5376.000000
# 24     6704.000000
# 25    18270.000000
# 26     5028.000000
# 27    16934.000000
# 28     9990.000000
# 29    16934.000000
# 30     1608.000000
# 31    17942.000000
# 32        0.000000

# %%
###########FINISHED 15:08


import pandas as pd

FinalPath='Test/FinalTableFees.csv'

# Load the CSV files
fees_2018 = pd.read_csv('Test/Grouped_Fees2019_by_Department_and_Level.csv')
fees_2019 = pd.read_csv('Test/Grouped_Fees2019_by_Department_and_Level.csv')
fees_2020 = pd.read_csv('Test/Grouped_Fees2020_by_Department_and_Level.csv')
fees_2021 = pd.read_csv('Test/Grouped_Fees2021_by_Department_and_Level.csv')
fees_2022 = pd.read_csv('Test/Grouped_Fees2022_by_Department_and_Level.csv')
fees_2023 = pd.read_csv('Test/Grouped_Fees2023_by_Department_and_Level.csv')
fees_2024 = pd.read_csv('Test/Grouped_Fees2024_by_Department_and_Level.csv')



# Merge 2023 and 2024 data
merged_fees = pd.merge(fees_2023, fees_2024, on=['Department', 'Level'], suffixes=('_2023', '_2024'))



# Rename the Fee Difference column for 2022 data
fees_2022.rename(columns={'Fee Difference': 'Fee Difference_2022'}, inplace=True)

# Extract the universal undergraduate fee for 2022
universal_undergrad_fee_2022 = fees_2022.loc[
    (fees_2022['Department'] == 'Department not found') & (fees_2022['Level'] == 'Undergraduate'),
    'Fee Difference_2022'
].values[0]

# Merge the 2022 data into the merged 2023 and 2024 data
final_merged_fees = pd.merge(merged_fees, fees_2022[['Department', 'Level', 'Fee Difference_2022']], on=['Department', 'Level'], how='left')

# Fill NaN values for undergraduate levels with the universal undergraduate fee for 2022
final_merged_fees.loc[(final_merged_fees['Level'] == 'Undergraduate') & (final_merged_fees['Fee Difference_2022'].isna()), 'Fee Difference_2022'] = universal_undergrad_fee_2022

# Reorder columns so that 'Fee Difference_2022' is to the left of 'Fee Difference_2023'
column_order = ['Department', 'Level', 'Fee Difference_2022', 'Fee Difference_2023', 'Fee Difference_2024']
final_merged_fees = final_merged_fees[column_order]




fees_2021.rename(columns={'Fee Difference': 'Fee Difference_2021'}, inplace=True)

universal_undergrad_fee_2021 = fees_2021.loc[
    (fees_2021['Department'] == 'Department not found') & (fees_2021['Level'] == 'Undergraduate'),
    'Fee Difference_2021'
].values[0]

final_merged_fees = pd.merge(final_merged_fees, fees_2021[['Department', 'Level', 'Fee Difference_2021']], on=['Department', 'Level'], how='left')

final_merged_fees.loc[(final_merged_fees['Level'] == 'Undergraduate') & (final_merged_fees['Fee Difference_2021'].isna()), 'Fee Difference_2021'] = universal_undergrad_fee_2021

column_order = ['Department', 'Level', 'Fee Difference_2021', 'Fee Difference_2022', 'Fee Difference_2023', 'Fee Difference_2024']
final_merged_fees = final_merged_fees[column_order]



fees_2020.rename(columns={'Fee Difference': 'Fee Difference_2020'}, inplace=True)

universal_undergrad_fee_2020 = fees_2020.loc[
    (fees_2020['Department'] == 'Department not found') & (fees_2020['Level'] == 'Undergraduate'),
    'Fee Difference_2020'
].values[0]

final_merged_fees = pd.merge(final_merged_fees, fees_2020[['Department', 'Level', 'Fee Difference_2020']], on=['Department', 'Level'], how='left')

final_merged_fees.loc[(final_merged_fees['Level'] == 'Undergraduate') & (final_merged_fees['Fee Difference_2020'].isna()), 'Fee Difference_2020'] = universal_undergrad_fee_2020

column_order = ['Department', 'Level', 'Fee Difference_2020', 'Fee Difference_2021','Fee Difference_2022', 'Fee Difference_2023', 'Fee Difference_2024']
final_merged_fees = final_merged_fees[column_order]



fees_2019.rename(columns={'Fee Difference': 'Fee Difference_2019'}, inplace=True)

universal_undergrad_fee_2019 = fees_2019.loc[
    (fees_2019['Department'] == 'Department not found') & (fees_2019['Level'] == 'Undergraduate'),
    'Fee Difference_2019'
].values[0]

final_merged_fees = pd.merge(final_merged_fees, fees_2019[['Department', 'Level', 'Fee Difference_2019']], on=['Department', 'Level'], how='left')

final_merged_fees.loc[(final_merged_fees['Level'] == 'Undergraduate') & (final_merged_fees['Fee Difference_2019'].isna()), 'Fee Difference_2019'] = universal_undergrad_fee_2019

column_order = ['Department', 'Level','Fee Difference_2019', 'Fee Difference_2020', 'Fee Difference_2021','Fee Difference_2022', 'Fee Difference_2023', 'Fee Difference_2024']
final_merged_fees = final_merged_fees[column_order]



fees_2018.rename(columns={'Fee Difference': 'Fee Difference_2018'}, inplace=True)

universal_undergrad_fee_2018 = fees_2018.loc[
    (fees_2018['Department'] == 'Department not found') & (fees_2018['Level'] == 'Undergraduate'),
    'Fee Difference_2018'
].values[0]

final_merged_fees = pd.merge(final_merged_fees, fees_2018[['Department', 'Level', 'Fee Difference_2018']], on=['Department', 'Level'], how='left')

final_merged_fees.loc[(final_merged_fees['Level'] == 'Undergraduate') & (final_merged_fees['Fee Difference_2018'].isna()), 'Fee Difference_2018'] = universal_undergrad_fee_2018

column_order = ['Department', 'Level','Fee Difference_2018','Fee Difference_2019', 'Fee Difference_2020', 'Fee Difference_2021','Fee Difference_2022', 'Fee Difference_2023', 'Fee Difference_2024']
final_merged_fees = final_merged_fees[column_order]


final_merged_fees.to_csv(FinalPath, index=False, encoding='utf-8-sig')


# Display the final table
display(final_merged_fees)
# Out:
#                                            Department          Level  \
# 0                                Department not found   Postgraduate
# 1                                Department not found  Undergraduate
# 2                            Department of Accounting   Postgraduate
# 3                            Department of Accounting  Undergraduate
# 4                          Department of Anthropology   Postgraduate
# 5                          Department of Anthropology  Undergraduate
# 6                      Department of Economic History   Postgraduate
# 7                      Department of Economic History  Undergraduate
# 8                             Department of Economics  Undergraduate
# 9                               Department of Finance  Undergraduate
# 10                       Department of Gender Studies   Postgraduate
# 11            Department of Geography and Environment   Postgraduate
# 12            Department of Geography and Environment  Undergraduate
# 13                           Department of Government   Postgraduate
# 14                           Department of Government  Undergraduate
# 15                        Department of Health Policy   Postgraduate
# 16            Department of International Development   Postgraduate
# 17                Department of International History  Undergraduate
# 18              Department of International Relations  Undergraduate
# 19                           Department of Management  Undergraduate
# 20                          Department of Mathematics   Postgraduate
# 21                          Department of Mathematics  Undergraduate
# 22             Department of Media and Communications   Postgraduate
# 23                          Department of Methodology   Postgraduate
# 24  Department of Philosophy Logic and Scientific ...   Postgraduate
# 25  Department of Philosophy, Logic and Scientific...  Undergraduate
# 26  Department of Psychological and Behavioural Sc...   Postgraduate
# 27                            Department of Sociology   Postgraduate
# 28                            Department of Sociology  Undergraduate
# 29                           Department of Statistics   Postgraduate
# 30                           Department of Statistics  Undergraduate
# 31                                 European Institute   Postgraduate
#
#     Fee Difference_2018  Fee Difference_2019  Fee Difference_2020  \
# 0           2321.540984          2321.540984          2362.983051
# 1          10670.000000         10670.000000         12320.000000
# 2            552.000000           552.000000           576.000000
# 3          10670.000000         10670.000000         12320.000000
# 4           7656.000000          7656.000000          7968.000000
# 5          10670.000000         10670.000000         12320.000000
# 6           7656.000000          7656.000000          7968.000000
# 7          10670.000000         10670.000000         12320.000000
# 8          10670.000000         10670.000000         12320.000000
# 9          10670.000000         10670.000000         12320.000000
# 10          7656.000000          7656.000000          7968.000000
# 11          6657.000000          6657.000000          6837.000000
# 12         10670.000000         10670.000000         12320.000000
# 13          7656.000000          7656.000000          7968.000000
# 14         10670.000000         10670.000000         12320.000000
# 15          7320.000000          7320.000000          7608.000000
# 16          3828.000000          3828.000000          3984.000000
# 17         10670.000000         10670.000000         12320.000000
# 18         10670.000000         10670.000000         12320.000000
# 19         10670.000000         10670.000000         12320.000000
# 20          4104.000000          4104.000000          4272.000000
# 21         10670.000000         10670.000000         12320.000000
# 22             0.000000             0.000000             0.000000
# 23          4104.000000          4104.000000          4272.000000
# 24          3828.000000          3828.000000          3984.000000
# 25         10670.000000         10670.000000         12320.000000
# 26          3828.000000          3828.000000          3984.000000
# 27          6545.142857          6545.142857          6809.142857
# 28         10670.000000         10670.000000         12320.000000
# 29           552.000000           552.000000           576.000000
# 30         10670.000000         10670.000000         12320.000000
# 31             0.000000             0.000000             0.000000
#
#     Fee Difference_2021  Fee Difference_2022  Fee Difference_2023  \
# 0           2409.684211          2761.655172               2865.5
# 1          13180.000000         14080.000000              15626.0
# 2            600.000000           624.000000                648.0
# 3          13180.000000         14080.000000              16406.0
# 4           8304.000000          8640.000000               9480.0
# 5          13180.000000         14080.000000              15470.0
# 6           8304.000000          8640.000000               9480.0
# 7          13180.000000         14080.000000              16094.0
# 8          13180.000000         14080.000000              17342.0
# 9          13180.000000         14080.000000              17342.0
# 10          8304.000000          8640.000000               9480.0
# 11          6328.000000          6536.000000               7200.0
# 12         13180.000000         14080.000000              15938.0
# 13          8304.000000             0.000000                  0.0
# 14         13180.000000         14080.000000              16218.8
# 15          5264.000000          5472.000000               6048.0
# 16          4152.000000          4320.000000               9480.0
# 17         13180.000000         14080.000000              15470.0
# 18         13180.000000         14080.000000              16406.0
# 19         13180.000000         14080.000000              16406.0
# 20          4452.000000          4632.000000               5064.0
# 21         13180.000000         14080.000000              16406.0
# 22             0.000000             0.000000                  0.0
# 23          4452.000000          4632.000000               5064.0
# 24          4152.000000          4320.000000               4740.0
# 25         13180.000000         14080.000000              16718.0
# 26          4152.000000          4320.000000               4740.0
# 27          7086.857143          7527.000000               9720.0
# 28         13180.000000         14080.000000              15470.0
# 29           600.000000           624.000000                648.0
# 30         13180.000000         14080.000000              16406.0
# 31             0.000000             0.000000                  0.0
#
#     Fee Difference_2024
# 0           2964.000000
# 1          17270.000000
# 2            696.000000
# 3          17942.000000
# 4          10056.000000
# 5          16934.000000
# 6           6024.000000
# 7          17598.000000
# 8          18926.000000
# 9          18926.000000
# 10         10056.000000
# 11          8597.333333
# 12         17438.000000
# 13             0.000000
# 14         17740.400000
# 15          6416.000000
# 16         10056.000000
# 17         16934.000000
# 18         17942.000000
# 19         17942.000000
# 20          5376.000000
# 21         17942.000000
# 22             0.000000
# 23          5376.000000
# 24          6704.000000
# 25         18270.000000
# 26          5028.000000
# 27          9990.000000
# 28         16934.000000
# 29          1608.000000
# 30         17942.000000
# 31             0.000000
