# %%
import requests
from bs4 import BeautifulSoup
import sqlite3


def view_database(db_file):
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    cursor.execute("SELECT * FROM gdp_by_country_data")
    rows = cursor.fetchall()

    print("Database contents:")
    for row in rows:
        print(row)

    conn.close()

# %%
def scrape_gdp_by_country():
    url = "https://www.worldometers.info/gdp/gdp-by-country/"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    rows = soup.find_all('tr')
    gdp_by_country_data = []

    for row in rows:
        cells = row.find_all('td')
        if len(cells) >= 7:
            country = cells[1].text.strip()
            gdp = cells[2].text.strip().replace('$', '').replace(',', '')
            population = cells[5].text.strip().replace(',', '')
            gdp_per_capita = cells[6].text.strip().replace('$', '').replace(',', '')
            gdp_by_country_data.append((country, gdp, population, gdp_per_capita))
    
    return gdp_by_country_data

def create_database(gdp_by_country_data):
    conn = sqlite3.connect('gdp_by_country.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS gdp_by_country_data (id INTEGER PRIMARY KEY, country TEXT UNIQUE, gdp REAL, population INTEGER, gdp_per_capita REAL)''')
    
    for country, gdp, population, gdp_per_capita in gdp_by_country_data:
        try:
            cursor.execute("INSERT INTO gdp_by_country_data (country, gdp, population, gdp_per_capita) VALUES (?, ?, ?, ?)", (country, gdp, population, gdp_per_capita))
        except sqlite3.IntegrityError:
            # Handle duplicate data
            pass
    
    conn.commit()
    conn.close()

def main():
    gdp_by_country_data = scrape_gdp_by_country()
    if gdp_by_country_data:
        create_database(gdp_by_country_data)

if __name__ == "__main__":
    main()

# %%
import csv
import sqlite3

def update_database(csv_file, db_file):
    # Read data from CSV file
    with open(csv_file, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        country_dict = {row['en_short_name']: row['nationality'] for row in reader}

    # Connect to the SQLite database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # Iterate over the country_dict and update the database
    for country_name, nationality in country_dict.items():
        try:
            cursor.execute("UPDATE gdp_by_country_data SET country = ? WHERE country = ?", (nationality, country_name))
        except sqlite3.IntegrityError:
            print(f"Duplicate entry found for {country_name}, skipping update.")

    # Commit changes and close connection
    conn.commit()
    conn.close()

# Call the function to update the database
update_database('Data/countries.csv', 'gdp_by_country.db')


view_database('gdp_by_country.db')
# Out:
# Duplicate entry found for Albania, skipping update.
# Duplicate entry found for Algeria, skipping update.
# Duplicate entry found for Andorra, skipping update.
# Duplicate entry found for Angola, skipping update.
# Duplicate entry found for Antigua and Barbuda, skipping update.
# Duplicate entry found for Argentina, skipping update.
# Duplicate entry found for Armenia, skipping update.
# Duplicate entry found for Australia, skipping update.
# Duplicate entry found for Austria, skipping update.
# Duplicate entry found for Azerbaijan, skipping update.
# Duplicate entry found for Bahamas, skipping update.
# Duplicate entry found for Bahrain, skipping update.
# Duplicate entry found for Bangladesh, skipping update.
# Duplicate entry found for Barbados, skipping update.
# Duplicate entry found for Belarus, skipping update.
# Duplicate entry found for Belgium, skipping update.
# Duplicate entry found for Belize, skipping update.
# Duplicate entry found for Benin, skipping update.
# Duplicate entry found for Bosnia and Herzegovina, skipping update.
# Duplicate entry found for Botswana, skipping update.
# Duplicate entry found for Brazil, skipping update.
# Duplicate entry found for Bulgaria, skipping update.
# Duplicate entry found for Burkina Faso, skipping update.
# Duplicate entry found for Burundi, skipping update.
# Duplicate entry found for Cabo Verde, skipping update.
# Duplicate entry found for Cambodia, skipping update.
# Duplicate entry found for Cameroon, skipping update.
# Duplicate entry found for Canada, skipping update.
# Duplicate entry found for Central African Republic, skipping update.
# Duplicate entry found for Chad, skipping update.
# Duplicate entry found for Chile, skipping update.
# Duplicate entry found for China, skipping update.
# Duplicate entry found for Colombia, skipping update.
# Duplicate entry found for Comoros, skipping update.
# Duplicate entry found for Costa Rica, skipping update.
# Duplicate entry found for Côte d'Ivoire, skipping update.
# Duplicate entry found for Croatia, skipping update.
# Duplicate entry found for Cyprus, skipping update.
# Duplicate entry found for Denmark, skipping update.
# Duplicate entry found for Dominica, skipping update.
# Duplicate entry found for Dominican Republic, skipping update.
# Duplicate entry found for Ecuador, skipping update.
# Duplicate entry found for Egypt, skipping update.
# Duplicate entry found for El Salvador, skipping update.
# Duplicate entry found for Equatorial Guinea, skipping update.
# Duplicate entry found for Estonia, skipping update.
# Duplicate entry found for Ethiopia, skipping update.
# Duplicate entry found for Fiji, skipping update.
# Duplicate entry found for Finland, skipping update.
# Duplicate entry found for France, skipping update.
# Duplicate entry found for Gabon, skipping update.
# Duplicate entry found for Gambia, skipping update.
# Duplicate entry found for Georgia, skipping update.
# Duplicate entry found for Germany, skipping update.
# Duplicate entry found for Ghana, skipping update.
# Duplicate entry found for Greece, skipping update.
# Duplicate entry found for Grenada, skipping update.
# Duplicate entry found for Guatemala, skipping update.
# Duplicate entry found for Guinea, skipping update.
# Duplicate entry found for Guinea-Bissau, skipping update.
# Duplicate entry found for Guyana, skipping update.
# Duplicate entry found for Haiti, skipping update.
# Duplicate entry found for Honduras, skipping update.
# Duplicate entry found for Hong Kong, skipping update.
# Duplicate entry found for Hungary, skipping update.
# Duplicate entry found for Iceland, skipping update.
# Duplicate entry found for India, skipping update.
# Duplicate entry found for Indonesia, skipping update.
# Duplicate entry found for Iran, skipping update.
# Duplicate entry found for Iraq, skipping update.
# Duplicate entry found for Ireland, skipping update.
# Duplicate entry found for Israel, skipping update.
# Duplicate entry found for Italy, skipping update.
# Duplicate entry found for Jamaica, skipping update.
# Duplicate entry found for Japan, skipping update.
# Duplicate entry found for Jordan, skipping update.
# Duplicate entry found for Kazakhstan, skipping update.
# Duplicate entry found for Kenya, skipping update.
# Duplicate entry found for Kiribati, skipping update.
# Duplicate entry found for Kuwait, skipping update.
# Duplicate entry found for Kyrgyzstan, skipping update.
# Duplicate entry found for Latvia, skipping update.
# Duplicate entry found for Lesotho, skipping update.
# Duplicate entry found for Liberia, skipping update.
# Duplicate entry found for Libya, skipping update.
# Duplicate entry found for Lithuania, skipping update.
# Duplicate entry found for Luxembourg, skipping update.
# Duplicate entry found for Macao, skipping update.
# Duplicate entry found for Madagascar, skipping update.
# Duplicate entry found for Malawi, skipping update.
# Duplicate entry found for Malaysia, skipping update.
# Duplicate entry found for Maldives, skipping update.
# Duplicate entry found for Mali, skipping update.
# Duplicate entry found for Malta, skipping update.
# Duplicate entry found for Marshall Islands, skipping update.
# Duplicate entry found for Mauritania, skipping update.
# Duplicate entry found for Mauritius, skipping update.
# Duplicate entry found for Mexico, skipping update.
# Duplicate entry found for Mongolia, skipping update.
# Duplicate entry found for Montenegro, skipping update.
# Duplicate entry found for Morocco, skipping update.
# Duplicate entry found for Mozambique, skipping update.
# Duplicate entry found for Myanmar, skipping update.
# Duplicate entry found for Namibia, skipping update.
# Duplicate entry found for Nepal, skipping update.
# Duplicate entry found for Netherlands, skipping update.
# Duplicate entry found for New Zealand, skipping update.
# Duplicate entry found for Nicaragua, skipping update.
# Duplicate entry found for Niger, skipping update.
# Duplicate entry found for Nigeria, skipping update.
# Duplicate entry found for Norway, skipping update.
# Duplicate entry found for Oman, skipping update.
# Duplicate entry found for Pakistan, skipping update.
# Duplicate entry found for Panama, skipping update.
# Duplicate entry found for Papua New Guinea, skipping update.
# Duplicate entry found for Paraguay, skipping update.
# Duplicate entry found for Peru, skipping update.
# Duplicate entry found for Philippines, skipping update.
# Duplicate entry found for Poland, skipping update.
# Duplicate entry found for Portugal, skipping update.
# Duplicate entry found for Qatar, skipping update.
# Duplicate entry found for Romania, skipping update.
# Duplicate entry found for Rwanda, skipping update.
# Duplicate entry found for Saint Lucia, skipping update.
# Duplicate entry found for Samoa, skipping update.
# Duplicate entry found for Saudi Arabia, skipping update.
# Duplicate entry found for Senegal, skipping update.
# Duplicate entry found for Serbia, skipping update.
# Duplicate entry found for Seychelles, skipping update.
# Duplicate entry found for Sierra Leone, skipping update.
# Duplicate entry found for Singapore, skipping update.
# Duplicate entry found for Slovakia, skipping update.
# Duplicate entry found for Slovenia, skipping update.
# Duplicate entry found for Solomon Islands, skipping update.
# Duplicate entry found for South Africa, skipping update.
# Duplicate entry found for Spain, skipping update.
# Duplicate entry found for Sri Lanka, skipping update.
# Duplicate entry found for Sudan, skipping update.
# Duplicate entry found for Suriname, skipping update.
# Duplicate entry found for Sweden, skipping update.
# Duplicate entry found for Switzerland, skipping update.
# Duplicate entry found for Tajikistan, skipping update.
# Duplicate entry found for Thailand, skipping update.
# Duplicate entry found for Timor-Leste, skipping update.
# Duplicate entry found for Togo, skipping update.
# Duplicate entry found for Trinidad and Tobago, skipping update.
# Duplicate entry found for Tunisia, skipping update.
# Duplicate entry found for Turkey, skipping update.
# Duplicate entry found for Tuvalu, skipping update.
# Duplicate entry found for Uganda, skipping update.
# Duplicate entry found for Ukraine, skipping update.
# Duplicate entry found for United Arab Emirates, skipping update.
# Duplicate entry found for Uruguay, skipping update.
# Duplicate entry found for Uzbekistan, skipping update.
# Duplicate entry found for Vanuatu, skipping update.
# Duplicate entry found for Vietnam, skipping update.
# Duplicate entry found for Zambia, skipping update.
# Duplicate entry found for Zimbabwe, skipping update.
# Database contents:
# (1, 'United States', 25462700000000.0, 338289857, 75269.0)
# (2, 'China', 17963200000000.0, 1425887337, 12598.0)
# (100, 'Papua New Guinea', 30633444295.0, 10142619, 3020.0)
# (101, 'Cambodia', 29956769529.0, 16767842, 1787.0)
# (102, 'Zambia', 29784454056.0, 20017675, 1488.0)
# (103, 'Cyprus', 28439052741.0, 1251488, 22724.0)
# (104, 'Trinidad and Tobago', 27899082337.0, 1531044, 18222.0)
# (105, 'Iceland', 27841648044.0, 372899, 74663.0)
# (106, 'Senegal', 27684430244.0, 17316449, 1599.0)
# (107, 'Georgia', 24605375420.0, 3744385, 6571.0)
# (108, 'Bosnia and Herzegovina', 24527507288.0, 3233526, 7585.0)
# (109, 'Macao', 21979475561.0, 695168, 31618.0)
# (110, 'Guinea', 21227749389.0, 13859341, 1532.0)
# (111, 'Gabon', 21071739228.0, 2388992, 8820.0)
# (112, 'Zimbabwe', 20678055598.0, 16320537, 1267.0)
# (113, 'Botswana', 20352322157.0, 2630296, 7738.0)
# (114, 'Haiti', 20253551885.0, 11584996, 1748.0)
# (115, 'Armenia', 19502783988.0, 2780469, 7014.0)
# (116, 'State of Palestine', 19111900000.0, 5250072, 3640.0)
# (117, 'Burkina Faso', 18884619613.0, 22673762, 833.0)
# (118, 'Albania', 18882095518.0, 2842321, 6643.0)
# (119, 'Mali', 18827176532.0, 22593590, 833.0)
# (120, 'Mozambique', 17851491428.0, 32969518, 541.0)
# (121, 'Malta', 17765270015.0, 533286, 33313.0)
# (122, 'Benin', 17401746309.0, 13352864, 1303.0)
# (123, 'Jamaica', 17097760745.0, 2827377, 6047.0)
# (124, 'Mongolia', 16810883361.0, 3398366, 4947.0)
# (125, 'Brunei', 16681531646.0, 449002, 37152.0)
# (126, 'Laos', 15724383783.0, 7529475, 2088.0)
# (127, 'Nicaragua', 15671583878.0, 6948392, 2255.0)
# (128, 'Guyana', 15357537068.0, 808726, 18990.0)
# (129, 'Madagascar', 14954967604.0, 29611714, 505.0)
# (130, 'Congo', 14615532210.0, 5970424, 2448.0)
# (131, 'Moldova', 14420947884.0, 3272996, 4406.0)
# (132, 'Niger', 13969605583.0, 26207977, 533.0)
# (133, 'North Macedonia', 13563132057.0, 2093599, 6478.0)
# (134, 'Rwanda', 13312796765.0, 13776698, 966.0)
# (135, 'Malawi', 13164667627.0, 20405317, 645.0)
# (136, 'Mauritius', 12898307089.0, 1299469, 9926.0)
# (137, 'Bahamas', 12897400000.0, 409984, 31458.0)
# (138, 'Chad', 12704149842.0, 17723315, 717.0)
# (139, 'Namibia', 12607436976.0, 2567012, 4911.0)
# (140, 'Equatorial Guinea', 11813908448.0, 1674908, 7053.0)
# (141, 'Kyrgyzstan', 10930644915.0, 6630623, 1649.0)
# (142, 'Tajikistan', 10492123388.0, 9952787, 1054.0)
# (143, 'Mauritania', 10375460680.0, 4736139, 2191.0)
# (144, 'Togo', 8126439481.0, 8848699, 918.0)
# (145, 'Maldives', 6189865408.0, 523787, 11818.0)
# (146, 'Montenegro', 6095978868.0, 627082, 9721.0)
# (147, 'Barbados', 5637914515.0, 281635, 20019.0)
# (148, 'Fiji', 4943248200.0, 929766, 5317.0)
# (149, 'Eswatini', 4854167638.0, 1201670, 4040.0)
# (150, 'Liberia', 4001047150.0, 5302681, 755.0)
# (151, 'Sierra Leone', 3970343852.0, 8605718, 461.0)
# (152, 'Suriname', 3620655116.0, 618040, 5858.0)
# (153, 'Andorra', 3352032737.0, 79824, 41993.0)
# (154, 'Timor-Leste', 3163324631.0, 1341296, 2358.0)
# (155, 'Burundi', 3073414678.0, 12889576, 238.0)
# (156, 'Belize', 2824081836.0, 405272, 6968.0)
# (157, 'Lesotho', 2553459763.0, 2305825, 1107.0)
# (158, 'Central African Republic', 2382618615.0, 5579144, 427.0)
# (159, 'Cabo Verde', 2314816792.0, 593149, 3903.0)
# (160, 'Gambia', 2273060863.0, 2705992, 840.0)
# (161, 'Saint Lucia', 2065027556.0, 179857, 11481.0)
# (162, 'Antigua and Barbuda', 1757603704.0, 93763, 18745.0)
# (163, 'Guinea-Bissau', 1633559092.0, 2105566, 776.0)
# (164, 'Solomon Islands', 1595710784.0, 724273, 2203.0)
# (165, 'Seychelles', 1588406479.0, 107118, 14829.0)
# (166, 'Grenada', 1256413185.0, 125438, 10016.0)
# (167, 'Comoros', 1242519407.0, 836774, 1485.0)
# (168, 'Vanuatu', 983582865.0, 326740, 3010.0)
# (169, 'Saint Kitts & Nevis', 961563259.0, 47657, 20177.0)
# (170, 'St. Vincent & Grenadines', 948558503.0, 103948, 9125.0)
# (171, 'Samoa', 832421565.0, 222382, 3743.0)
# (172, 'Dominica', 612048148.0, 72737, 8415.0)
# (173, 'Sao Tome & Principe', 546680342.0, 227380, 2404.0)
# (174, 'Micronesia', 427094119.0, 539013, 792.0)
# (175, 'Marshall Islands', 279667900.0, 41569, 6728.0)
# (176, 'Kiribati', 223352943.0, 131232, 1702.0)
# (177, 'Tuvalu', 60349391.0, 11312, 5335.0)
# (178, 'Chinese', 17963200000000.0, 1425887337, 12598.0)
# (179, 'Japanese', 4231140000000.0, 123951692, 34135.0)
# (180, 'German', 4072190000000.0, 83369843, 48845.0)
# (181, 'Indian', 3385090000000.0, 1417173173, 2389.0)
# (182, 'French', 2782910000000.0, 64626628, 43061.0)
# (183, 'Canadian', 2139840000000.0, 38454327, 55646.0)
# (184, 'Italian', 2010430000000.0, 59037474, 34053.0)
# (185, 'Brazilian', 1920100000000.0, 215313498, 8918.0)
# (186, 'Australian', 1675420000000.0, 26177413, 64003.0)
# (187, 'Mexican', 1414190000000.0, 127504125, 11091.0)
# (188, 'Spanish', 1397510000000.0, 47558630, 29385.0)
# (189, 'Indonesian', 1319100000000.0, 275501339, 4788.0)
# (190, 'Saudi, Saudi Arabian', 1108150000000.0, 36408820, 30436.0)
# (191, 'Dutch, Netherlandic', 991115000000.0, 17564014, 56429.0)
# (192, 'Turkish', 905988000000.0, 85341241, 10616.0)
# (193, 'Swiss', 807706000000.0, 8740472, 92410.0)
# (194, 'Polish', 688177000000.0, 39857145, 17266.0)
# (195, 'Argentine', 632770000000.0, 45510318, 13904.0)
# (196, 'Swedish', 585939000000.0, 10549347, 55543.0)
# (197, 'Norwegian', 579267000000.0, 5434319, 106594.0)
# (198, 'Belgian', 578604000000.0, 11655930, 49640.0)
# (199, 'Irish', 529245000000.0, 5023109, 105362.0)
# (200, 'Israeli', 522033000000.0, 9038309, 57758.0)
# (201, 'Emirati, Emirian, Emiri', 507535000000.0, 9441129, 53758.0)
# (202, 'Thai', 495341000000.0, 71697030, 6909.0)
# (203, 'Nigerian', 477386000000.0, 218541212, 2184.0)
# (204, 'Egyptian', 476748000000.0, 110990103, 4295.0)
# (205, 'Austrian', 471400000000.0, 8939617, 52732.0)
# (206, 'Singaporean', 466789000000.0, 5975689, 78115.0)
# (207, 'Bangladeshi', 460201000000.0, 171186372, 2688.0)
# (208, 'Vietnamese', 408802000000.0, 98186856, 4164.0)
# (209, 'Malaysian', 406306000000.0, 33938221, 11972.0)
# (210, 'South African', 405870000000.0, 59893885, 6776.0)
# (211, 'Philippine, Filipino', 404284000000.0, 115559009, 3499.0)
# (212, 'Danish', 395404000000.0, 5882261, 67220.0)
# (213, 'Iranian, Persian', 388544000000.0, 88550570, 4388.0)
# (214, 'Pakistani', 376533000000.0, 235824862, 1597.0)
# (215, 'Hong Kong, Hong Kongese', 359839000000.0, 7488865, 48050.0)
# (216, 'Colombian', 343939000000.0, 51874024, 6630.0)
# (217, 'Romanian', 301262000000.0, 19659267, 15324.0)
# (218, 'Chilean', 301025000000.0, 19603733, 15355.0)
# (219, 'Finnish', 280826000000.0, 5540745, 50684.0)
# (220, 'Iraqi', 264182000000.0, 44496122, 5937.0)
# (221, 'Portuguese', 251945000000.0, 10270865, 24530.0)
# (222, 'New Zealand, NZ', 247234000000.0, 5185288, 47680.0)
# (223, 'Peruvian', 242632000000.0, 34049588, 7126.0)
# (224, 'Qatari', 237296000000.0, 2695122, 88046.0)
# (225, 'Kazakhstani, Kazakh', 220623000000.0, 19397998, 11373.0)
# (226, 'Greek, Hellenic', 219066000000.0, 10384971, 21095.0)
# (227, 'Algerian', 191913000000.0, 44903225, 4274.0)
# (228, 'Kuwaiti', 184558000000.0, 4268873, 43233.0)
# (229, 'Hungarian, Magyar', 178789000000.0, 9967308, 17938.0)
# (230, 'Ukrainian', 160503000000.0, 39701739, 4043.0)
# (231, 'Moroccan', 134182000000.0, 37457971, 3582.0)
# (232, 'Ethiopian', 126783000000.0, 123379924, 1028.0)
# (233, 'Slovak', 115469000000.0, 5643453, 20461.0)
# (234, 'Ecuadorian', 115049000000.0, 18001000, 6391.0)
# (235, 'Omani', 114667000000.0, 4576298, 25057.0)
# (236, 'Dominican', 113642000000.0, 11228821, 10121.0)
# (237, 'Kenyan', 113420000000.0, 54027487, 2099.0)
# (238, 'Angolan', 106714000000.0, 35588987, 2999.0)
# (239, 'Guatemalan', 95003333381.0, 17843908, 5324.0)
# (240, 'Bulgarian', 89040398406.0, 6781953, 13129.0)
# (241, 'Luxembourg, Luxembourgish', 82274812251.0, 647599, 127046.0)
# (242, 'Uzbekistani, Uzbek', 80391853885.0, 34627652, 2322.0)
# (243, 'Azerbaijani, Azeri', 78721058824.0, 10358074, 7600.0)
# (244, 'Panamanian', 76522511781.0, 4408581, 17358.0)
# (245, 'Sri Lankan', 74403578363.0, 21832143, 3408.0)
# (246, 'Ghanaian', 72838798788.0, 33475870, 2176.0)
# (247, 'Belarusian', 72793457588.0, 9534954, 7634.0)
# (248, 'Uruguayan', 71177146197.0, 3422794, 20795.0)
# (249, 'Croatian', 70964606465.0, 4030358, 17608.0)
# (250, 'Lithuanian', 70334299008.0, 2750055, 25576.0)
# (251, 'Ivorian', 70018715017.0, 28160542, 2486.0)
# (252, 'Costa Rican', 68380838316.0, 5180829, 13199.0)
# (253, 'Serbian', 63501748652.0, 7221365, 8794.0)
# (254, 'Slovenian, Slovene', 62117768015.0, 2119844, 29303.0)
# (255, 'Burmese', 59364362541.0, 54179306, 1096.0)
# (256, 'Sudanese', 51662241775.0, 46874204, 1102.0)
# (257, 'Jordanian', 47451499859.0, 11285869, 4205.0)
# (258, 'Tunisian', 46664948952.0, 12356117, 3777.0)
# (259, 'Libyan', 45752336036.0, 6812341, 6716.0)
# (260, 'Ugandan', 45559202049.0, 47249585, 964.0)
# (261, 'Bahraini', 44390820479.0, 1472233, 30152.0)
# (262, 'Cameroonian', 44341646509.0, 27914536, 1588.0)
# (263, 'Paraguayan', 41722295362.0, 6780744, 6153.0)
# (264, 'Latvian', 41153912663.0, 1850651, 22238.0)
# (265, 'Nepali, Nepalese', 40828247302.0, 30547580, 1337.0)
# (266, 'Estonian', 38100812959.0, 1326062, 28732.0)
# (267, 'Salvadoran', 32488720000.0, 6336392, 5127.0)
# (268, 'Honduran', 31717700115.0, 10432860, 3040.0)
# (269, 'Papua New Guinean, Papuan', 30633444295.0, 10142619, 3020.0)
# (270, 'Cambodian', 29956769529.0, 16767842, 1787.0)
# (271, 'Zambian', 29784454056.0, 20017675, 1488.0)
# (272, 'Cypriot', 28439052741.0, 1251488, 22724.0)
# (273, 'Trinidadian or Tobagonian', 27899082337.0, 1531044, 18222.0)
# (274, 'Icelandic', 27841648044.0, 372899, 74663.0)
# (275, 'Senegalese', 27684430244.0, 17316449, 1599.0)
# (276, 'Georgian', 24605375420.0, 3744385, 6571.0)
# (277, 'Bosnian or Herzegovinian', 24527507288.0, 3233526, 7585.0)
# (278, 'Macanese, Chinese', 21979475561.0, 695168, 31618.0)
# (279, 'Guinean', 21227749389.0, 13859341, 1532.0)
# (280, 'Gabonese', 21071739228.0, 2388992, 8820.0)
# (281, 'Zimbabwean', 20678055598.0, 16320537, 1267.0)
# (282, 'Motswana, Botswanan', 20352322157.0, 2630296, 7738.0)
# (283, 'Haitian', 20253551885.0, 11584996, 1748.0)
# (284, 'Armenian', 19502783988.0, 2780469, 7014.0)
# (285, 'Burkinabé', 18884619613.0, 22673762, 833.0)
# (286, 'Albanian', 18882095518.0, 2842321, 6643.0)
# (287, 'Malian, Malinese', 18827176532.0, 22593590, 833.0)
# (288, 'Mozambican', 17851491428.0, 32969518, 541.0)
# (289, 'Maltese', 17765270015.0, 533286, 33313.0)
# (290, 'Beninese, Beninois', 17401746309.0, 13352864, 1303.0)
# (291, 'Jamaican', 17097760745.0, 2827377, 6047.0)
# (292, 'Mongolian', 16810883361.0, 3398366, 4947.0)
# (293, 'Nicaraguan', 15671583878.0, 6948392, 2255.0)
# (294, 'Guyanese', 15357537068.0, 808726, 18990.0)
# (295, 'Malagasy', 14954967604.0, 29611714, 505.0)
# (296, 'Nigerien', 13969605583.0, 26207977, 533.0)
# (297, 'Rwandan', 13312796765.0, 13776698, 966.0)
# (298, 'Malawian', 13164667627.0, 20405317, 645.0)
# (299, 'Mauritian', 12898307089.0, 1299469, 9926.0)
# (300, 'Bahamian', 12897400000.0, 409984, 31458.0)
# (301, 'Chadian', 12704149842.0, 17723315, 717.0)
# (302, 'Namibian', 12607436976.0, 2567012, 4911.0)
# (303, 'Equatorial Guinean, Equatoguinean', 11813908448.0, 1674908, 7053.0)
# (304, 'Kyrgyzstani, Kyrgyz, Kirgiz, Kirghiz', 10930644915.0, 6630623, 1649.0)
# (305, 'Tajikistani', 10492123388.0, 9952787, 1054.0)
# (306, 'Mauritanian', 10375460680.0, 4736139, 2191.0)
# (307, 'Togolese', 8126439481.0, 8848699, 918.0)
# (308, 'Maldivian', 6189865408.0, 523787, 11818.0)
# (309, 'Montenegrin', 6095978868.0, 627082, 9721.0)
# (310, 'Barbadian', 5637914515.0, 281635, 20019.0)
# (311, 'Fijian', 4943248200.0, 929766, 5317.0)
# (312, 'Liberian', 4001047150.0, 5302681, 755.0)
# (313, 'Sierra Leonean', 3970343852.0, 8605718, 461.0)
# (314, 'Surinamese', 3620655116.0, 618040, 5858.0)
# (315, 'Andorran', 3352032737.0, 79824, 41993.0)
# (316, 'Timorese', 3163324631.0, 1341296, 2358.0)
# (317, 'Burundian', 3073414678.0, 12889576, 238.0)
# (318, 'Belizean', 2824081836.0, 405272, 6968.0)
# (319, 'Basotho', 2553459763.0, 2305825, 1107.0)
# (320, 'Central African', 2382618615.0, 5579144, 427.0)
# (321, 'Cabo Verdean', 2314816792.0, 593149, 3903.0)
# (322, 'Gambian', 2273060863.0, 2705992, 840.0)
# (323, 'Saint Lucian', 2065027556.0, 179857, 11481.0)
# (324, 'Antiguan or Barbudan', 1757603704.0, 93763, 18745.0)
# (325, 'Bissau-Guinean', 1633559092.0, 2105566, 776.0)
# (326, 'Solomon Island', 1595710784.0, 724273, 2203.0)
# (327, 'Seychellois', 1588406479.0, 107118, 14829.0)
# (328, 'Grenadian', 1256413185.0, 125438, 10016.0)
# (329, 'Comoran, Comorian', 1242519407.0, 836774, 1485.0)
# (330, 'Ni-Vanuatu, Vanuatuan', 983582865.0, 326740, 3010.0)
# (331, 'Samoan', 832421565.0, 222382, 3743.0)
# (332, 'Marshallese', 279667900.0, 41569, 6728.0)
# (333, 'I-Kiribati', 223352943.0, 131232, 1702.0)
# (334, 'Tuvaluan', 60349391.0, 11312, 5335.0)
